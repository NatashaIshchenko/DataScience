# %% [markdown]
# # Matplotlib - библиотека для рисовния графиков, картинок

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # plot (график)

# %%
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x,y,'green')
plt.plot(y,x,'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # imshow - рисование images

# %%
import requests
from PIL import Image
from io import BytesIO

response = requests.get('http://www.renemagritte.org/images/paintings/the-lovers-2.jpg')
img = Image.open(BytesIO(response.content))
ima = np.asanyarray(img)

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x676 at 0x1A3A9AE3438>

# %%
print(ima)
# Out:
# [[[229 210 203]
#   [220 201 194]
#   [209 190 183]
#   ...
#   [182 149 132]
#   [178 147 129]
#   [174 143 125]]
#
#  [[213 194 187]
#   [199 180 173]
#   [190 172 162]
#   ...
#   [129  96  79]
#   [144 113  95]
#   [142 111  93]]
#
#  [[212 194 184]
#   [190 172 162]
#   [190 172 162]
#   ...
#   [139 106  89]
#   [157 124 107]
#   [152 121 103]]
#
#  ...
#
#  [[157 191 192]
#   [ 81 115 116]
#   [ 96 130 132]
#   ...
#   [ 79  59  58]
#   [ 76  56  55]
#   [101  81  80]]
#
#  [[167 201 202]
#   [ 79 113 114]
#   [ 88 122 124]
#   ...
#   [ 86  66  65]
#   [ 85  65  64]
#   [111  91  90]]
#
#  [[172 206 207]
#   [ 80 114 115]
#   [ 92 126 128]
#   ...
#   [ 98  78  77]
#   [ 98  78  77]
#   [125 105 104]]]

# %%
plt.imshow(ima)
